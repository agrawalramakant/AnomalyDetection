# %%
import matplotlib.pyplot as plt
from collections import OrderedDict
#erro = [(30, 0.093878954607978016), (31, 0.095254470426409887), (32, 0.10247592847317744), (33, 0.092847317744154112), (34, 0.093878954607978016), (35, 0.09319119669876208), (36, 0.095598349381017855), (37, 0.099381017881705613), (38, 0.098693259972489678), (39, 0.095598349381017855), (40, 0.096286107290233791), (41, 0.09834938101788171), (42, 0.095598349381017855), (43, 0.092159559834938065), (44, 0.095254470426409887), (45, 0.092847317744154112), (46, 0.093535075653370048), (47, 0.094222833562585984), (48, 0.098693259972489678), (49, 0.094910591471801919), (50, 0.094910591471801919), (51, 0.090784044016506193), (52, 0.093878954607978016), (53, 0.095942228335625823), (54, 0.099381017881705613), (55, 0.092503438789546033), (56, 0.093535075653370048), (57, 0.094566712517193952), (58, 0.089408528198074322), (59, 0.092159559834938065), (60, 0.093535075653370048), (61, 0.092159559834938065), (62, 0.093535075653370048), (63, 0.094910591471801919), (64, 0.092159559834938065), (65, 0.094910591471801919), (66, 0.091127922971114161), (67, 0.090096286107290258), (68, 0.093535075653370048), (69, 0.095942228335625823), (70, 0.095254470426409887), (71, 0.090784044016506193), (72, 0.092503438789546033), (73, 0.092159559834938065), (74, 0.092503438789546033), (75, 0.090096286107290258), (76, 0.095254470426409887), (77, 0.086657496561210468), (78, 0.094222833562585984), (79, 0.093878954607978016), (80, 0.094222833562585984), (81, 0.09319119669876208), (82, 0.090784044016506193), (83, 0.092847317744154112), (84, 0.094222833562585984), (85, 0.090096286107290258), (86, 0.088720770288858275), (87, 0.094566712517193952), (88, 0.094566712517193952), (89, 0.091815680880330097), (90, 0.09834938101788171), (91, 0.092503438789546033), (92, 0.09319119669876208), (93, 0.08975240715268229), (94, 0.091127922971114161), (95, 0.089064649243466354), (96, 0.091815680880330097), (97, 0.093535075653370048), (98, 0.094910591471801919), (99, 0.094566712517193952), (100, 0.092503438789546033)]
erro = OrderedDict([('RandomForestClassifier, max_features=None', [(30, 0.094222833562585984), (31, 0.094566712517193952), (32, 0.095598349381017855), (33, 0.094566712517193952), (34, 0.09319119669876208), (35, 0.092503438789546033), (36, 0.094222833562585984), (37, 0.094222833562585984), (38, 0.094910591471801919), (39, 0.094910591471801919), (40, 0.093878954607978016), (41, 0.093878954607978016), (42, 0.095942228335625823), (43, 0.093535075653370048), (44, 0.094910591471801919), (45, 0.094910591471801919), (46, 0.094222833562585984), (47, 0.095598349381017855), (48, 0.095254470426409887), (49, 0.094910591471801919), (50, 0.094566712517193952), (51, 0.094910591471801919), (52, 0.094222833562585984), (53, 0.094566712517193952), (54, 0.094222833562585984), (55, 0.09319119669876208), (56, 0.093535075653370048), (57, 0.093535075653370048), (58, 0.09319119669876208), (59, 0.092847317744154112), (60, 0.091127922971114161), (61, 0.091127922971114161), (62, 0.091471801925722129), (63, 0.091815680880330097), (64, 0.090440165061898226), (65, 0.08975240715268229), (66, 0.08975240715268229), (67, 0.090440165061898226), (68, 0.090096286107290258), (69, 0.089408528198074322), (70, 0.08975240715268229), (71, 0.090784044016506193), (72, 0.091471801925722129), (73, 0.090784044016506193), (74, 0.091471801925722129), (75, 0.091127922971114161), (76, 0.091471801925722129), (77, 0.091127922971114161), (78, 0.091127922971114161), (79, 0.091471801925722129), (80, 0.091127922971114161), (81, 0.091815680880330097), (82, 0.092159559834938065), (83, 0.092503438789546033), (84, 0.092503438789546033), (85, 0.093535075653370048), (86, 0.092847317744154112), (87, 0.092847317744154112), (88, 0.093535075653370048), (89, 0.09319119669876208), (90, 0.093878954607978016), (91, 0.093878954607978016), (92, 0.093878954607978016), (93, 0.093878954607978016), (94, 0.092847317744154112), (95, 0.092159559834938065), (96, 0.092847317744154112), (97, 0.09319119669876208), (98, 0.094222833562585984), (99, 0.092847317744154112), (100, 0.092159559834938065)])])
ensemble_clfs = [ ("RandomForestClassifier, max_features=None",RandomForestClassifier(warm_start=True, max_features=None, oob_score=True,))]

for label, clf_err in erro.items():
    xs, ys = zip(*clf_err)
    plt.plot(xs, ys, label=label)

plt.xlim(min_estimators, max_estimators)
plt.xlabel("n_estimators")
plt.ylabel("OOB error rate")
plt.legend(loc="upper right")
plt.show()

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
# raw_train = np.loadtxt("yelp_data_train.dat", delimiter=";",dtype=str)

# print raw_train
np.set_printoptions(threshold=np.nan)
def readDataset(dataset_name, data_col, content_loc):
    data = []
    count = 0
    with open("challenge_data/"+dataset_name) as file:
        header = file.readline()
        # csv_content = csv.reader(file, delimiter=';')
        # print csv_content
        for line in file:
            if line.strip().endswith(';'):
                line = line.strip() + file.next()
            temparr = line.strip().split(';')
            if len(temparr) > data_col:
                extra_col = len(temparr) - data_col
                for index in range(extra_col):
                    temptext = temparr.pop(content_loc + 1)
                    temparr[content_loc] = temparr[content_loc] +", "+ temptext
                    # index -= 1
            if len(temparr) == data_col:
                # print temparr
                data.append(temparr)
                count += 1
            else:
                print temparr


    print count
    return header, np.array(data)
from collections import defaultdict
def read_hotel_dataset(dataset_name):
    data = defaultdict(list)
    # data.setdefault([])
    with open ("challenge_data/"+dataset_name) as file:
        header = file.readline()

        for line in file:

            temparr = line.strip().split(';')
            if len(temparr) == 13:
                try:
                    data[temparr[0]] = temparr
                except:
                    print len(data)
    return header, data
# id,date,reviewID,reviewerID,reviewContent,rating,usefulCount,coolCount,funnyCount,hotelID
# date,reviewID,reviewerID,reviewContent,rating,usefulCount,coolCount,funnyCount,fake,hotelID
def read_test_dataset():
    data = []

# print count
header_review, data_review = readDataset("yelp_data_train.dat", 10,3)
header_test, data_test = readDataset("yelp_data_test.dat",10,4)
header_user, data_user = read_hotel_dataset("yelp_data_reviewer.dat")
header_hotel, data_hotel = read_hotel_dataset("yelp_data_hotel.dat")
# print data_hotel.shape
print header_hotel
print header_review
print header_user
# print len(data_hotel)
data_review[data_review == 'Y'] = 1
data_review[data_review == 'N'] = 0
# np.loadtxt("yelp_data_train.dat", delimiter=';',skiprows=1,dtype=str)
R_REVIEW_ID = 0
R_DATE = 1
R_REVIEWER_ID = 2
R_USEFUL_COUNT = 3
R_COOL_COUNT = 4
R_FUNNY_COUNT = 5
R_RATING = 6
R_TYPE = 7
R_REVIEW_CONTENT = 8
R_HOTEL_ID = 9
U_LOCATION = 10
U_JOIN_DATE = 11
U_REVIEW_COUNT = 12
U_FRIEND_COUNT = 13
U_FIRST_COUNT = 14
U_USEFUL_COUNT = 15
U_COOL_COUNT = 16
U_FUNNY_COUNT = 17
U_COMPLIMENT_COUNT = 18
U_TIP_COUNT = 19
U_FAN_COUNT = 20
H_LOCATION = 21
H_REVIEW_COUNT = 22
H_RATING = 23

# work_data_set = np.array((13,len(data_review)))
#
# work_data_set[REVIEW_ID] = data_review[1]
work_data_set = [None] * 24
work_data_set[R_REVIEW_ID] = data_review[:,1]
work_data_set[R_DATE] = data_review[:,0]
work_data_set[R_REVIEWER_ID] = data_review[:,2]
work_data_set[R_USEFUL_COUNT] = data_review[:,5]
work_data_set[R_COOL_COUNT] = data_review[:,6]
work_data_set[R_FUNNY_COUNT] = data_review[:,7]
work_data_set[R_REVIEW_CONTENT] = data_review[:,3]
work_data_set[R_HOTEL_ID] = data_review[:,9]
work_data_set[R_RATING] = data_review[:,4]
work_data_set[R_TYPE] = data_review[:,8]

# for test
test_work = [None] * 24
test_work[R_REVIEW_ID] = data_test[:,2]
test_work[R_DATE] = data_test[:,1]
test_work[R_REVIEWER_ID] = data_test[:,3]
test_work[R_USEFUL_COUNT] = data_test[:,6]
test_work[R_COOL_COUNT] = data_test[:,7]
test_work[R_FUNNY_COUNT] = data_test[:,8]
test_work[R_REVIEW_CONTENT] = data_test[:,4]
test_work[R_HOTEL_ID] = data_test[:,9]
test_work[R_RATING] = data_test[:,5]
test_work[R_TYPE] = data_test[:,8]
# print len(data_review)
temp_U_LOCATION = []
temp_U_JOIN_DATE = []
temp_U_REVIEW_COUNT = []
temp_U_FRIEND_COUNT = []
temp_U_FIRST_COUNT = []
temp_U_USEFUL_COUNT = []
temp_U_COOL_COUNT = []
temp_U_FUNNY_COUNT = []
temp_U_COMPLIMENT_COUNT = []
temp_U_TIP_COUNT = []
temp_U_FAN_COUNT = []

temp_H_LOCATION = []
temp_H_REVIEW_COUNT = []
temp_H_RATING = []
#
# work_data_set[H_LOCATION] = []
# work_data_set[H_REVIEW_COUNT] = []
# work_data_set[H_RATING] = []
# print len(work_data_set[7])
# print len(work_data_set[6])
# print len(work_data_set[5])
# print len(work_data_set[4])
# print len(work_data_set[3])
# print np.array(work_data_set).shape
count_match = 0
for index in range(len(data_review)):
    # flag = False
    # no_deleted = 0

    review = data_review[index]
    # for item in data_user:
    if review[2] in data_user:
        # print item
        count_match += 1
        item = data_user[review[2]]
        # if item[0] == review[2]:
        temp_U_LOCATION.append(item[2])
        temp_U_JOIN_DATE.append(item[3])
        temp_U_REVIEW_COUNT.append(item[5])
        temp_U_FRIEND_COUNT.append(item[4])
        temp_U_FIRST_COUNT.append(item[6])
        temp_U_USEFUL_COUNT.append(item[7])
        temp_U_COOL_COUNT.append(item[8])
        temp_U_FUNNY_COUNT.append(item[9])
        temp_U_COMPLIMENT_COUNT.append(item[10])
        temp_U_TIP_COUNT.append(item[11])
        temp_U_FAN_COUNT.append(item[12])

    else:

        temp_U_LOCATION.append(item[2])
        temp_U_JOIN_DATE.append(item[3])
        temp_U_REVIEW_COUNT.append(item[5])
        temp_U_FRIEND_COUNT.append(item[4])
        temp_U_FIRST_COUNT.append(item[6])
        temp_U_USEFUL_COUNT.append(item[7])
        temp_U_COOL_COUNT.append(item[8])
        temp_U_FUNNY_COUNT.append(item[9])
        temp_U_COMPLIMENT_COUNT.append(item[10])
        temp_U_TIP_COUNT.append(item[11])
        temp_U_FAN_COUNT.append(item[12])

    if review[9] in data_hotel:
        item_h = data_hotel[review[9]]
        temp_H_LOCATION.append(item_h[2])
        temp_H_REVIEW_COUNT.append(item_h[3])
        temp_H_RATING.append(item_h[4])
    else:
        print "not found"
print count_match

t_temp_U_LOCATION = []
t_temp_U_JOIN_DATE = []
t_temp_U_REVIEW_COUNT = []
t_temp_U_FRIEND_COUNT = []
t_temp_U_FIRST_COUNT = []
t_temp_U_USEFUL_COUNT = []
t_temp_U_COOL_COUNT = []
t_temp_U_FUNNY_COUNT = []
t_temp_U_COMPLIMENT_COUNT = []
t_temp_U_TIP_COUNT = []
t_temp_U_FAN_COUNT = []
t_temp_H_LOCATION = []
t_temp_H_REVIEW_COUNT = []
t_temp_H_RATING = []

for index in range(len(data_test)):
    # flag = False
    # no_deleted = 0

    review = data_test[index]
    # for item in data_user:
    if review[2] in data_user:
        # print item
        count_match += 1
        item = data_user[review[2]]
        # if item[0] == review[2]:
        t_temp_U_LOCATION.append(item[2])
        t_temp_U_JOIN_DATE.append(item[3])
        t_temp_U_REVIEW_COUNT.append(item[5])
        t_temp_U_FRIEND_COUNT.append(item[4])
        t_temp_U_FIRST_COUNT.append(item[6])
        t_temp_U_USEFUL_COUNT.append(item[7])
        t_temp_U_COOL_COUNT.append(item[8])
        t_temp_U_FUNNY_COUNT.append(item[9])
        t_temp_U_COMPLIMENT_COUNT.append(item[10])
        t_temp_U_TIP_COUNT.append(item[11])
        t_temp_U_FAN_COUNT.append(item[12])

    else:

        t_temp_U_LOCATION.append(item[2])
        t_temp_U_JOIN_DATE.append(item[3])
        t_temp_U_REVIEW_COUNT.append(item[5])
        t_temp_U_FRIEND_COUNT.append(item[4])
        t_temp_U_FIRST_COUNT.append(item[6])
        t_temp_U_USEFUL_COUNT.append(item[7])
        t_temp_U_COOL_COUNT.append(item[8])
        t_temp_U_FUNNY_COUNT.append(item[9])
        t_temp_U_COMPLIMENT_COUNT.append(item[10])
        t_temp_U_TIP_COUNT.append(item[11])
        t_temp_U_FAN_COUNT.append(item[12])

    if review[9] in data_hotel:
        item_h = data_hotel[review[9]]
        t_temp_H_LOCATION.append(item_h[2])
        t_temp_H_REVIEW_COUNT.append(item_h[3])
        t_temp_H_RATING.append(item_h[4])
    else:
        print "not found"
# print len(work_data_set[U_LOCATION])
    # for item in data_hotel:
    #     if item[0] == user[9]:
    #         work_data_set[H_LOCATION .append(item[2])
    #         work_data_set[H_REVIEW_COUNT].append(item[3])
    #         work_data_set[H_RATING].append(item[4])

work_data_set[U_LOCATION] = np.array(temp_U_LOCATION)
work_data_set[U_JOIN_DATE] = np.array(temp_U_JOIN_DATE)
work_data_set[U_REVIEW_COUNT] = np.array(temp_U_REVIEW_COUNT)
work_data_set[U_FRIEND_COUNT] = np.array(temp_U_FRIEND_COUNT)
work_data_set[U_FIRST_COUNT] = np.array(temp_U_FIRST_COUNT)
work_data_set[U_USEFUL_COUNT] = np.array(temp_U_USEFUL_COUNT)
work_data_set[U_COOL_COUNT] = np.array(temp_U_COOL_COUNT)
work_data_set[U_FUNNY_COUNT] = np.array(temp_U_FUNNY_COUNT)
work_data_set[U_COMPLIMENT_COUNT] = np.array(temp_U_COMPLIMENT_COUNT)
work_data_set[U_TIP_COUNT] = np.array(temp_U_TIP_COUNT)
work_data_set[U_FAN_COUNT] = np.array(temp_U_FAN_COUNT)
work_data_set[H_LOCATION] = np.array(temp_H_LOCATION)
work_data_set[H_REVIEW_COUNT] = np.array(temp_H_REVIEW_COUNT)
work_data_set[H_RATING] = np.array(temp_H_RATING)
new_work = np.array(work_data_set)
print new_work.shape

work = new_work.transpose()
print work.shape

test_work[U_LOCATION] = np.array(t_temp_U_LOCATION)
test_work[U_JOIN_DATE] = np.array(t_temp_U_JOIN_DATE)
test_work[U_REVIEW_COUNT] = np.array(t_temp_U_REVIEW_COUNT)
test_work[U_FRIEND_COUNT] = np.array(t_temp_U_FRIEND_COUNT)
test_work[U_FIRST_COUNT] = np.array(t_temp_U_FIRST_COUNT)
test_work[U_USEFUL_COUNT] = np.array(t_temp_U_USEFUL_COUNT)
test_work[U_COOL_COUNT] = np.array(t_temp_U_COOL_COUNT)
test_work[U_FUNNY_COUNT] = np.array(t_temp_U_FUNNY_COUNT)
test_work[U_COMPLIMENT_COUNT] = np.array(t_temp_U_COMPLIMENT_COUNT)
test_work[U_TIP_COUNT] = np.array(t_temp_U_TIP_COUNT)
test_work[U_FAN_COUNT] = np.array(t_temp_U_FAN_COUNT)
test_work[H_LOCATION] = np.array(t_temp_H_LOCATION)
test_work[H_REVIEW_COUNT] = np.array(t_temp_H_REVIEW_COUNT)
test_work[H_RATING] = np.array(t_temp_H_RATING)
new_test = np.array(test_work)
print new_test.shape

test = new_test.transpose()
print test.shape
# print work[:,R_TYPE]
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
def classifyRandomForestClassifier(XTrain, XTest, YTrain, YTest):
    clf = RandomForestClassifier(n_estimators=55, oob_score=0.01,random_state=0)
    # clf = KNeighborsClassifier(n_neighbors=3)
    clf.fit(XTrain, YTrain)
    YPred = clf.predict(XTest)
    score = 0
    for idx in range(len(YPred)):
        if YPred[idx] == YTest[idx]:
            score += 1
    # diff = YPred - YTest
    # score = diff[diff == 0].size
    return (100.0 * score)/(YPred.size)

from sklearn.cross_validation import StratifiedKFold
def kFoldCrossVal(XTrain, YTrain):
    n_folds = 10
    score = 0.0
    skf = StratifiedKFold(YTrain, n_folds)
    for train_index, test_index in skf:
        X_train, X_test = XTrain[train_index], XTrain[test_index]
        y_train, y_test = YTrain[train_index], YTrain[test_index]
        score += classifyRandomForestClassifier(X_train, X_test, y_train, y_test)
    return score / n_folds



print kFoldCrossVal(work[:,[R_USEFUL_COUNT,R_COOL_COUNT,R_FUNNY_COUNT,R_RATING,U_REVIEW_COUNT,U_FRIEND_COUNT,U_FIRST_COUNT,U_USEFUL_COUNT,U_COOL_COUNT,U_FUNNY_COUNT,U_COMPLIMENT_COUNT,U_TIP_COUNT,U_FAN_COUNT, H_REVIEW_COUNT,H_RATING]],work[:,R_TYPE])


min_estimators = 30
max_estimators = 100
error_rate = []

# for i in range(min_estimators, max_estimators + 1):
#     clf = RandomForestClassifier(warm_start=True, max_features=None, oob_score=True,)
#     clf.set_params(n_estimators=i)
#     clf.fit(work[:,[R_USEFUL_COUNT,R_COOL_COUNT,R_FUNNY_COUNT,R_RATING,U_REVIEW_COUNT,U_FRIEND_COUNT,U_FIRST_COUNT,U_USEFUL_COUNT,U_COOL_COUNT,U_FUNNY_COUNT,U_COMPLIMENT_COUNT,U_TIP_COUNT,U_FAN_COUNT, H_REVIEW_COUNT,H_RATING]],work[:,R_TYPE])
#     oob_error = 1 - clf.oob_score_
#     error_rate.append((i, oob_error))

erro = [(30, 0.093878954607978016), (31, 0.095254470426409887), (32, 0.10247592847317744), (33, 0.092847317744154112), (34, 0.093878954607978016), (35, 0.09319119669876208), (36, 0.095598349381017855), (37, 0.099381017881705613), (38, 0.098693259972489678), (39, 0.095598349381017855), (40, 0.096286107290233791), (41, 0.09834938101788171), (42, 0.095598349381017855), (43, 0.092159559834938065), (44, 0.095254470426409887), (45, 0.092847317744154112), (46, 0.093535075653370048), (47, 0.094222833562585984), (48, 0.098693259972489678), (49, 0.094910591471801919), (50, 0.094910591471801919), (51, 0.090784044016506193), (52, 0.093878954607978016), (53, 0.095942228335625823), (54, 0.099381017881705613), (55, 0.092503438789546033), (56, 0.093535075653370048), (57, 0.094566712517193952), (58, 0.089408528198074322), (59, 0.092159559834938065), (60, 0.093535075653370048), (61, 0.092159559834938065), (62, 0.093535075653370048), (63, 0.094910591471801919), (64, 0.092159559834938065), (65, 0.094910591471801919), (66, 0.091127922971114161), (67, 0.090096286107290258), (68, 0.093535075653370048), (69, 0.095942228335625823), (70, 0.095254470426409887), (71, 0.090784044016506193), (72, 0.092503438789546033), (73, 0.092159559834938065), (74, 0.092503438789546033), (75, 0.090096286107290258), (76, 0.095254470426409887), (77, 0.086657496561210468), (78, 0.094222833562585984), (79, 0.093878954607978016), (80, 0.094222833562585984), (81, 0.09319119669876208), (82, 0.090784044016506193), (83, 0.092847317744154112), (84, 0.094222833562585984), (85, 0.090096286107290258), (86, 0.088720770288858275), (87, 0.094566712517193952), (88, 0.094566712517193952), (89, 0.091815680880330097), (90, 0.09834938101788171), (91, 0.092503438789546033), (92, 0.09319119669876208), (93, 0.08975240715268229), (94, 0.091127922971114161), (95, 0.089064649243466354), (96, 0.091815680880330097), (97, 0.093535075653370048), (98, 0.094910591471801919), (99, 0.094566712517193952), (100, 0.092503438789546033)]

for clf_err in erro:
    xs, ys = zip(*clf_err)
    plt.plot(xs, ys, label="RF")

plt.xlim(min_estimators, max_estimators)
plt.xlabel("n_estimators")
plt.ylabel("OOB error rate")
plt.legend(loc="upper right")
plt.show()
clf = RandomForestClassifier(n_estimators=55, oob_score=0.01,random_state=0)
# clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(work[:,[R_USEFUL_COUNT,R_COOL_COUNT,R_FUNNY_COUNT,R_RATING,U_REVIEW_COUNT,U_FRIEND_COUNT,U_FIRST_COUNT,U_USEFUL_COUNT,U_COOL_COUNT,U_FUNNY_COUNT,U_COMPLIMENT_COUNT,U_TIP_COUNT,U_FAN_COUNT, H_REVIEW_COUNT,H_RATING]],work[:,R_TYPE])
prediction = clf.predict(test[:,[R_USEFUL_COUNT,R_COOL_COUNT,R_FUNNY_COUNT,R_RATING,U_REVIEW_COUNT,U_FRIEND_COUNT,U_FIRST_COUNT,U_USEFUL_COUNT,U_COOL_COUNT,U_FUNNY_COUNT,U_COMPLIMENT_COUNT,U_TIP_COUNT,U_FAN_COUNT, H_REVIEW_COUNT,H_RATING]])

with open("Pred_RF.csv", "w") as f:
    f.write("Id,Expected" + "\n")
    for i in range(len(prediction)):
        f.write(str(i) + "," + str(int(prediction[i])) + "\n")
# Out:
# ['']
# ['']
# ['']
# 2908
# 2950
# hotelID;name;location;reviewCount;rating;categories;address;AcceptsCreditCards;PriceRange;WiFi;webSite;phoneNumber;filReviewCount
#
# date,reviewID,reviewerID,reviewContent,rating,usefulCount,coolCount,funnyCount,fake,hotelID
#
# reviewerID;name;location;yelpJoinDate;friendCount;reviewCount;firstCount;usefulCount;coolCount;funnyCount;complimentCount;tipCount;fanCount
#
# 2903
# (24, 2908)
# (2908, 24)
# (24, 2950)
# (2950, 24)
# 89.4117137166
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-63fad237f0cc> in <module>()
#     342
#     343 for clf_err in error_rate:
# --> 344     xs, ys = zip(*clf_err)
#     345     plt.plot(xs, ys, label="RF")
#     346
#
# TypeError: zip argument #1 must support iteration
